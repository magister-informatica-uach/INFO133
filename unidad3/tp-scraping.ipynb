# %%
import requests
#import urllib.request as request
#import time
from bs4 import BeautifulSoup

# %%
url = 'https://www.eldesconcierto.cl/2019/05/13/padres-de-nino-actor-usado-en-campana-del-mineduc-manifiestan-su-rechazo-a-admision-justa/'

# %%
doc = requests.get(url)
doc.text
# Out:
# '\n\n<!doctype html>\n<!--[if lt IE 7]>      <html class="no-js lt-ie9 lt-ie8 lt-ie7" lang="es"> <![endif]-->\n<!--[if IE 7]>         <html class="no-js lt-ie9 lt-ie8" lang="es"> <![endif]-->\n<!--[if IE 8]>         <html class="no-js lt-ie9" lang="es"> <![endif]-->\n<!--[if gt IE 8]><!--> <html class="no-js" lang="es"> <!--<![endif]-->\n    <head>\n        <meta charset="utf-8">\n        <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">\n\n        <title>Padres de niÃ±o-actor usado en campaÃ±a del Mineduc manifiestan su rechazo a AdmisiÃ³n Justa | El Desconcierto</title>\n\n        <meta name="description" content="Prensa Digital Libre">\n        <meta name="viewport" content="width=device-width, initial-scale=1">\n\n        \n        <link href="//www.google-analytics.com" rel="dns-prefetch">\n\n                <link href=\'https://fonts.googleapis.com/css?family=Merriweather:400,400italic,700,700italic\' rel=\'stylesheet\' type=\'text/css\'>\n        <link href="https://fonts.googleapis.com/css?family=Francois+One|Bree+Serif|Open+Sans:300,400,400i,600,700,800,900" rel="stylesheet">\n        <link rel="stylesheet" type="text/css" href="https://www.eldesconcierto.cl/wp-content/themes/desconcierto_2017_4.1/css/normalize.css">\n        <link rel="stylesheet" type="text/css" href="https://www.eldesconcierto.cl/wp-content/themes/desconcierto_2017_4.1/js/owl-carousel/owl.carousel.css">\n        <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/OwlCarousel2/2.3.4/assets/owl.carousel.min.css">\n        <link rel="stylesheet" type="text/css" href="https://www.eldesconcierto.cl/wp-content/themes/desconcierto_2017_4.1/js/owl-carousel/owl.theme.css">\n        <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/flexslider/2.7.1/flexslider.min.css">\n        <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/magnific-popup.js/1.1.0/magnific-popup.min.css">\n        <link rel="stylesheet" type="text/css" href="https://www.eldesconcierto.cl/wp-content/themes/desconcierto_2017_4.1/css/main.css?ver=20180226">\n        <link rel="stylesheet" type="text/css" href="https://www.eldesconcierto.cl/wp-content/themes/desconcierto_2017_4.1/css/style-mobile.css?ver=20180226">\n        <link rel="stylesheet" type="text/css" href="https://www.eldesconcierto.cl/wp-content/themes/desconcierto_2017_4.1/css/new.css?ver=0">\n        <link rel="stylesheet" type="text/css" href="https://www.eldesconcierto.cl/wp-content/themes/desconcierto_2017_4.1/css/especial.css?ver=120180226">\n        <link rel="stylesheet" type="text/css" href="https://www.eldesconcierto.cl/wp-content/themes/desconcierto_2017_4.1/css/subela.css?ver=11120180226">\n        <style>#subela *, #subela *:before, #subela *:after{ box-sizing: border-box; }</style>\n\n\n        <link rel="apple-touch-icon" sizes="57x57" href="https://www.eldesconcierto.cl/wp-content/themes/desconcierto_2017_4.1/iconos/apple-icon-57x57.png">\n        <link rel="apple-touch-icon" sizes="60x60" href="https://www.eldesconcierto.cl/wp-content/themes/desconcierto_2017_4.1/iconos/apple-icon-60x60.png">\n        <link rel="apple-touch-icon" sizes="72x72" href="https://www.eldesconcierto.cl/wp-content/themes/desconcierto_2017_4.1/iconos/apple-icon-72x72.png">\n        <link rel="apple-touch-icon" sizes="76x76" href="https://www.eldesconcierto.cl/wp-content/themes/desconcierto_2017_4.1/iconos/apple-icon-76x76.png">\n        <link rel="apple-touch-icon" sizes="114x114" href="https://www.eldesconcierto.cl/wp-content/themes/desconcierto_2017_4.1/iconos/apple-icon-114x114.png">\n        <link rel="apple-touch-icon" sizes="120x120" href="https://www.eldesconcierto.cl/wp-content/themes/desconcierto_2017_4.1/iconos/apple-icon-120x120.png">\n        <link rel="apple-touch-icon" sizes="144x144" href="https://www.eldesconcierto.cl/wp-content/themes/desconcierto_2017_4.1/iconos/apple-icon-144x144.png">\n        <link rel="apple-touch-icon" sizes="152x152" href="https://www ...

# %%
from newspaper import Article
article = Article(url)

# %%
article.download()
article.parse()
print(article.title)
print(article.text)
# Out:
# Padres de niño-actor usado en campaña del Mineduc manifiestan su rechazo a Admisión Justa
# Sigue la polémica por la utilización de la imagen de un niño para hacer propaganda del proyecto Admisión Justa impulsado por la ministra de Educación, Marcela Cubillos.
#
# Esta vez fueron los padres del estudiante, Elías Collado, quienes criticaron al Mineduc y manifestaron su rechazo al proyecto que busca reinstalar la selección por mérito.
#
# “Nuestra visita a La Moneda fue por una invitación como alumno destacado de un colegio gratuito… si se usó la imagen y una de las frases dichas por Elías es una tema ético de quien la usó, no nuestro, créame que nuestra intención está muy lejana de apoyar alguna campaña de este tipo”, sostuvieron en una publicación de Instagram que fue difundida por la diputada del Partido Socialista, Daniela Cicardini.
#
# “Además ya hicimos ver nuestro malestar y prohibición de vincularlo a la materia“, agregaron.

# %%
article.authors
# Out:
# ['El Desconcierto']

# %%
article.publish_date
# Out:
# datetime.datetime(2019, 5, 13, 0, 0)
